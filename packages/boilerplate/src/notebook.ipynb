# %% [markdown]
# # Boilerplate
#
# > Data: **2026-01-01**
# >
# > Autore: **Luigi Malaguti**

# %% [markdown]
# ##
#
# ---

# %% [markdown]
# ## Parte 0: Il Dataset
#
# Dataset text.

# %% [markdown]
# ### Imports

# %%
# !curl -sLo dataset.zip "https://link"
# !unzip -o dataset.zip
# !mv file.csv dataset.csv
# FILE_ID = "file_id"
# !curl -sLo dataset.csv "https://drive.google.com/uc?export=download&id={FILE_ID}"

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Dataset

# %%
df = pd.read_csv("dataset.csv")

# %% [markdown]
# #### Overview

# %%
df.head()

# %%
df.info()

# %% [markdown]
# #### Instances

# %%
df.shape

# %% [markdown]
# #### Missing values

# %%
df.isnull().sum().sum()

# %% [markdown]
# #### Balancing

# %%
df["column"].value_counts()

# %%
df["column"].hist()

# %% [markdown]
# ##
#
# ---

# %% [markdown]
# ## Parte I: Analisi (Punti 0)

# %% [markdown]
# ### Domanda 01 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 02 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 03 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 04 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ##
#
# ---

# %% [markdown]
# ## Parte II: Trasformazione e Predizione (Punti 0)

# %% [markdown]
# ### Domanda 01 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 02 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 03 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 04 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 05 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 06 (Punti 0)
#
# Question test

# %%
# Code

# %% [markdown]
# ---

# %% [markdown]
# ### Domanda 07 (Punti 0)
#
# Question test

# %%
# Code
